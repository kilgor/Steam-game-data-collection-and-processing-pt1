# %%
import os
import pandas as pd

def process_game_data(main_folder):
    # List of required files
    required_files = [
        'overview.csv', 'copies sold.csv', 'revenue.csv', 'top seller rank.csv',
        'ccu.csv', 'price.csv', 'review.csv', 'followers.csv',
        'average playtime.csv', 'outstanding wishlist.csv', 'positive reviews.csv'
    ]
    
    # Initialize a DataFrame to store game info
    df_info = pd.DataFrame(columns=['game_name', 'location'])

    # Iterate through each subfolder in the main folder
    for game_folder in os.listdir(main_folder):
        game_path = os.path.join(main_folder, game_folder)
        if os.path.isdir(game_path):
            # Check if all required files are present
            if all(os.path.isfile(os.path.join(game_path, file)) for file in required_files):
                # Load each file into a DataFrame
                df_overview = pd.read_csv(os.path.join(game_path, 'overview.csv'))
                df_copies_sold = pd.read_csv(os.path.join(game_path, 'copies sold.csv'))
                df_revenue = pd.read_csv(os.path.join(game_path, 'revenue.csv'))
                df_top_seller_rank = pd.read_csv(os.path.join(game_path, 'top seller rank.csv'))
                df_ccu = pd.read_csv(os.path.join(game_path, 'ccu.csv'))
                df_price = pd.read_csv(os.path.join(game_path, 'price.csv'))
                df_reviews = pd.read_csv(os.path.join(game_path, 'review.csv'))
                df_followers = pd.read_csv(os.path.join(game_path, 'followers.csv'))
                df_average_playtime = pd.read_csv(os.path.join(game_path, 'average playtime.csv'))
                df_outstanding_wishlist = pd.read_csv(os.path.join(game_path, 'outstanding wishlist.csv'))
                df_positive_reviews = pd.read_csv(os.path.join(game_path, 'positive reviews.csv'))

                # Process df_price based on the number of columns
                if len(df_price.columns) > 2:
                    df_price = df_price.T
                    df_price = df_price[1:]
                    df_price = df_price.reset_index()
                    df_price = df_price.rename(columns={'index': 'date'})
                    df_price['date'] = df_price['date'].str[4:]
                    df_price = df_price.rename(columns={0: 'price'})
                else:
                    df_price = df_price.rename(columns={'x': 'date', 'y': 'price'})
                    df_price['date'] = pd.to_datetime(df_price['date'], unit='ms')
                    filled_rows = []
                    for i in range(len(df_price) - 1):
                        current_price = df_price.loc[i, 'price']
                        current_date = df_price.loc[i, 'date']
                        next_date = df_price.loc[i + 1, 'date']
                        date_range = pd.date_range(start=current_date, end=next_date, freq='D')
                        for date in date_range:
                            filled_rows.append({'date': date, 'price': current_price})
                    filled_rows.append({'date': df_price.loc[len(df_price) - 1, 'date'], 'price': df_price.loc[len(df_price) - 1, 'price']})
                    df_price = pd.DataFrame(filled_rows)
                    df_price.reset_index(drop=True, inplace=True)
                    df_price['date'] = df_price['date'].dt.normalize()
                    df_price = df_price.drop_duplicates(subset='date', keep='first').reset_index(drop=True)
                    df_price = df_price.drop(df_price.index[-1])

                # Process other DataFrames
                def process_df(df, column_name):
                    df = df.T
                    df = df[1:]
                    df = df.reset_index()
                    df = df.rename(columns={'index': 'date'})
                    df['date'] = df['date'].str[4:]
                    df = df.rename(columns={0: column_name})
                    return df

                df_copies_sold = process_df(df_copies_sold, 'copies sold')
                df_revenue = process_df(df_revenue, 'revenue')
                df_top_seller_rank = process_df(df_top_seller_rank, 'top seller rank')
                df_ccu = process_df(df_ccu, 'ccu')
                df_reviews = process_df(df_reviews, 'reviews')
                df_followers = process_df(df_followers, 'followers')
                df_average_playtime = process_df(df_average_playtime, 'average playtime')
                df_outstanding_wishlist = process_df(df_outstanding_wishlist, 'outstanding wishlist')
                df_positive_reviews = process_df(df_positive_reviews, 'positive reviews')

                # Process df_overview
                tag_categories = {
                    'tag game type': [
                        'Action Roguelike', '2D Platformer', 'Hack and Slash', 'Roguelite', 'Action RPG', 'FPS', 'Multiplayer',
                        'Open World', 'Survival', 'Crafting', 'Co-op Campaign', 'Base Building', 'Simulation', 'Exploration',
                        'Visual Novel', 'Shooter', 'RPG', 'Strategy', 'Sandbox', 'Action-Adventure', 'Sports', 'Puzzle', 'Fighting',
                        'Roguelike', 'Adventure', 'Card Game', 'RTS'
                    ],
                    'tag style': [
                        'Souls-like', 'Cyberpunk', 'Story Rich', 'Multiple Endings', 'Anime', 'Pixel Graphics', 'Retro', 'Cartoony',
                        'Fantasy', 'Dark Fantasy', 'Comedy', 'LGBTQ+', 'Realistic', 'Gothic', 'Mythology', 'Noir', 'Dystopian',
                        'Sci-fi', 'Lovecraftian', 'Atmospheric', 'Cute'
                    ],
                    'tag mechanics': [
                        'Side Scroller', 'Controller', 'Choices Matter', 'Crafting', 'Base Building', 'Co-op Campaign',
                        'Turn-Based', 'Real-Time', 'Procedural Generation', 'Deckbuilding', 'Inventory Management',
                        'Physics', 'Roguelike Deckbuilder', 'Tactical', 'PvP', 'PvE', 'Resource Management', 'Exploration', 'Combat',
                        'Building', 'Moddable', 'Level Editor', 'Narration'
                    ],
                    'tag perspective': [
                        '2D', '3D', 'Isometric', 'First-Person', 'Third Person', 'Top-Down', 'Side-Scrolling', 'Third-Person Shooter',
                        'VR', 'Over-the-Shoulder', '3D Vision', '2.5D', 'First-Person Shooter'
                    ]
                }

                def categorize_tags(tag_string, categories):
                    tags = tag_string.split(',')
                    categorized = {key: [] for key in categories}
                    for tag in tags:
                        tag = tag.strip()
                        found = False
                        for category, keywords in categories.items():
                            if tag in keywords:
                                categorized[category].append(tag)
                                found = True
                        if not found:
                            continue
                    for category in categorized:
                        if not categorized[category]:
                            categorized[category] = ['-']
                    return categorized

                for category in tag_categories.keys():
                    df_overview[category] = df_overview['tags'].apply(lambda x: ', '.join(categorize_tags(x, tag_categories)[category]) if pd.notnull(x) else '-')
                df_overview = df_overview.drop(columns=['tags'])

                df_overview = df_overview.drop(columns=['languages', 'price', 'features', 'early access exit date', 'description', 'first release date'])
                genres_split = df_overview['genres'].str.split(',', expand=True)
                df_overview = df_overview.assign(
                    genre_1=genres_split.get(0, '-'),
                    genre_2=genres_split.get(1, '-'),
                    genre_3=genres_split.get(2, '-')
                )
                cols = df_overview.columns.tolist()
                dev_idx = cols.index('developers')
                new_cols_order = cols[:dev_idx+1] + ['genre_1', 'genre_2', 'genre_3'] + cols[dev_idx+1:]
                df_overview = df_overview[new_cols_order]
                df_overview = df_overview.drop(columns=['genres'])

                df_overview_repeated = pd.concat([df_overview]*len(df_price), ignore_index=True)
                df_game = pd.concat([df_overview_repeated.reset_index(drop=True), df_price.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_copies_sold.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_revenue.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_top_seller_rank.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_ccu.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_reviews.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_followers.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_average_playtime.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_outstanding_wishlist.reset_index(drop=True)], axis=1)
                df_game = pd.concat([df_game, df_positive_reviews.reset_index(drop=True)], axis=1)
                df_game = df_game.loc[:, ~df_game.columns.duplicated(keep='first')]

                is_free_game = df_price['price'].eq(0).all()
                df_game['free game'] = is_free_game
                if not is_free_game:
                    non_zero_price_index = df_price[df_price['price'] != 0].index
                    df_game = df_game.loc[non_zero_price_index].reset_index(drop=True)
                    df_price = df_price.loc[non_zero_price_index].reset_index(drop=True)

                df_game['daily copies sold'] = df_game['copies sold'].diff().fillna(0)
                df_game['daily revenue'] = df_game['revenue'].diff().fillna(0)
                df_game['daily reviews'] = df_game['reviews'].diff().fillna(0)
                df_game['daily outstanding wishlist'] = df_game['outstanding wishlist'].diff().fillna(0)

                gameinfo_path = os.path.join(game_path, 'gameinfo.csv')
                df_game.to_csv(gameinfo_path, index=False)
                print(f"Game info for {game_folder} saved at {gameinfo_path}")

                df_info = pd.concat([df_info, pd.DataFrame({'game_name': [game_folder], 'location': [gameinfo_path]})], ignore_index=True)

    df_info.to_csv(os.path.join(main_folder, 'game_info_summary.csv'), index=False)

    # Combine all gameinfo.csv files into a massive DataFrame
    df_steamgame = pd.DataFrame()
    for game_folder in os.listdir(main_folder):
        game_path = os.path.join(main_folder, game_folder)
        gameinfo_path = os.path.join(game_path, 'gameinfo.csv')
        if os.path.isfile(gameinfo_path):
            df_game = pd.read_csv(gameinfo_path)
            df_steamgame = pd.concat([df_steamgame, df_game], ignore_index=True)

    df_steamgame.to_csv(os.path.join(main_folder, 'df_steamgame.csv'), index=False)
    print("ALL TASKS DONE!!!!!!")

# Example usage
main_folder = '../data/raw/game lib'
process_game_data(main_folder)
# Out:
# Game info for Abiotic Factor saved at ../data/raw/game lib\Abiotic Factor\gameinfo.csv
# Game info for Ace Attorney Investigations Collection saved at ../data/raw/game lib\Ace Attorney Investigations Collection\gameinfo.csv
# Game info for Age of Mythology Retold saved at ../data/raw/game lib\Age of Mythology Retold\gameinfo.csv
# Game info for Alone in the Dark saved at ../data/raw/game lib\Alone in the Dark\gameinfo.csv
# Game info for ANIMAL WELL saved at ../data/raw/game lib\ANIMAL WELL\gameinfo.csv
# Game info for Anomaly Agent saved at ../data/raw/game lib\Anomaly Agent\gameinfo.csv
# Game info for Another Crabs Treasure saved at ../data/raw/game lib\Another Crabs Treasure\gameinfo.csv
# Game info for Apollo Justice Ace Attorney Trilogy saved at ../data/raw/game lib\Apollo Justice Ace Attorney Trilogy\gameinfo.csv
# Game info for ASKA saved at ../data/raw/game lib\ASKA\gameinfo.csv
# Game info for ASTRA Knights of Veda saved at ../data/raw/game lib\ASTRA Knights of Veda\gameinfo.csv
# Game info for Astral Party saved at ../data/raw/game lib\Astral Party\gameinfo.csv
# Game info for Atelier Resleriana Forgotten Alchemy and the Polar Night Liberator saved at ../data/raw/game lib\Atelier Resleriana Forgotten Alchemy and the Polar Night Liberator\gameinfo.csv
# Game info for Avatar Frontiers of Pandora saved at ../data/raw/game lib\Avatar Frontiers of Pandora\gameinfo.csv
# Game info for Backpack Battles saved at ../data/raw/game lib\Backpack Battles\gameinfo.csv
# Game info for Balatro saved at ../data/raw/game lib\Balatro\gameinfo.csv
# Game info for Banishers Ghosts of New Eden saved at ../data/raw/game lib\Banishers Ghosts of New Eden\gameinfo.csv
# Game info for Bellwright saved at ../data/raw/game lib\Bellwright\gameinfo.csv
# Game info for Black Myth Wukong saved at ../data/raw/game lib\Black Myth Wukong\gameinfo.csv
# Game info for BMX Streets saved at ../data/raw/game lib\BMX Streets\gameinfo.csv
# Game info for Bodycam saved at ../data/raw/game lib\Bodycam\gameinfo.csv
# Game info for Buckshot Roulette saved at ../data/raw/game lib\Buckshot Roulette\gameinfo.csv
# Game info for BUNNY GARDEN saved at ../data/raw/game lib\BUNNY GARDEN\gameinfo.csv
# Game info for CarX Street saved at ../data/raw/game lib\CarX Street\gameinfo.csv
# Game info for Cataclismo saved at ../data/raw/game lib\Cataclismo\gameinfo.csv
# Game info for Chained Together saved at ../data/raw/game lib\Chained Together\gameinfo.csv
# Game info for Chinese Online Game saved at ../data/raw/game lib\Chinese Online Game\gameinfo.csv
# Game info for Content Warning saved at ../data/raw/game lib\Content Warning\gameinfo.csv
# Game info for ContractVille saved at ../data/raw/game lib\ContractVille\gameinfo.csv
# Game info for Crime Boss Rockay City saved at ../data/raw/game lib\Crime Boss Rockay City\gameinfo.csv
# Game info for Crime Scene Cleaner saved at ../data/raw/game lib\Crime Scene Cleaner\gameinfo.csv
# Game info for Dark and Darker saved at ../data/raw/game lib\Dark and Darker\gameinfo.csv
# Game info for Dead Island 2 saved at ../data/raw/game lib\Dead Island 2\gameinfo.csv
# Game info for Deep Rock Galactic Survivor saved at ../data/raw/game lib\Deep Rock Galactic Survivor\gameinfo.csv
# Game info for Dragons Dogma 2 saved at ../data/raw/game lib\Dragons Dogma 2\gameinfo.csv
# Game info for Drug Dealer Simulator 2 saved at ../data/raw/game lib\Drug Dealer Simulator 2\gameinfo.csv
# Game info for Dungeonborne saved at ../data/raw/game lib\Dungeonborne\gameinfo.csv
# Game info for Dusk Pub saved at ../data/raw/game lib\Dusk Pub\gameinfo.csv
# Game info for EA SPORTS Madden NFL 25 saved at ../data/raw/game lib\EA SPORTS Madden NFL 25\gameinfo.csv
# Game info for EARTH DEFENSE FORCE 6 saved at ../data/raw/game lib\EARTH DEFENSE FORCE 6\gameinfo.csv
# Game info for Eiyuden Chronicle Hundred Heroes saved at ../data/raw/game lib\Eiyuden Chronicle Hundred Heroes\gameinfo.csv
# Game info for ENDER MAGNOLIA Bloom in the Mist saved at ../data/raw/game lib\ENDER MAGNOLIA Bloom in the Mist\gameinfo.csv
# Game info for Enshrouded saved at ../data/raw/game lib\Enshrouded\gameinfo.csv
# Game info for Expeditions A MudRunner Game saved at ../data/raw/game lib\Expeditions A MudRunner Game\gameinfo.csv
# Game info for F1 24 saved at ../data/raw/game lib\F1 24\gameinfo.csv
# Game info for F1 Manager 2024 saved at ../data/raw/game lib\F1 Manager 2024\gameinfo.csv
# Game info for Feed the Cups saved at ../data/raw/game lib\Feed the Cups\gameinfo.csv
# Game info for Fields of Mistria saved at ../data/raw/game lib\Fields of Mistria\gameinfo.csv
# Game info for Five Nights at Freddys Into the Pit saved at ../data/raw/game lib\Five Nights at Freddys Into the Pit\gameinfo.csv
# Game info for FOUNDRY saved at ../data/raw/game lib\FOUNDRY\gameinfo.csv
# Game info for Ghost of Tsushima DIRECTORS CUT saved at ../data/raw/game lib\Ghost of Tsushima DIRECTORS CUT\gameinfo.csv
# Game info for Goat Simulator 3 saved at ../data/raw/game lib\Goat Simulator 3\gameinfo.csv
# Game info for Granblue Fantasy Relink saved at ../data/raw/game lib\Granblue Fantasy Relink\gameinfo.csv
# Game info for Gray Zone Warfare saved at ../data/raw/game lib\Gray Zone Warfare\gameinfo.csv
# Game info for GUNDAM BREAKER 4 saved at ../data/raw/game lib\GUNDAM BREAKER 4\gameinfo.csv
# Game info for Hades 2 saved at ../data/raw/game lib\Hades 2\gameinfo.csv
# Game info for Harry Potter Quidditch Champions saved at ../data/raw/game lib\Harry Potter Quidditch Champions\gameinfo.csv
# Game info for HELLDIVERS 2 saved at ../data/raw/game lib\HELLDIVERS 2\gameinfo.csv
# Game info for Homeworld 3 saved at ../data/raw/game lib\Homeworld 3\gameinfo.csv
# Game info for Horizon Forbidden West Complete Edition saved at ../data/raw/game lib\Horizon Forbidden West Complete Edition\gameinfo.csv
# Game info for Incursion Red River saved at ../data/raw/game lib\Incursion Red River\gameinfo.csv
# Game info for INDIKA saved at ../data/raw/game lib\INDIKA\gameinfo.csv
# Game info for Infection Free Zone saved at ../data/raw/game lib\Infection Free Zone\gameinfo.csv
# Game info for Into the Radius 2 saved at ../data/raw/game lib\Into the Radius 2\gameinfo.csv
# Game info for Jujutsu Kaisen Cursed Clash saved at ../data/raw/game lib\Jujutsu Kaisen Cursed Clash\gameinfo.csv
# Game info for Kebab Chefs  Restaurant Simulator saved at ../data/raw/game lib\Kebab Chefs  Restaurant Simulator\gameinfo.csv
# Game info for Killer Klowns from Outer Space The Game saved at ../data/raw/game lib\Killer Klowns from Outer Space The Game\gameinfo.csv
# Game info for KINGDOM HEARTS 3  Re Mind DLC saved at ../data/raw/game lib\KINGDOM HEARTS 3  Re Mind DLC\gameinfo.csv
# Game info for KINGDOM HEARTS HD 1525 ReMIX saved at ../data/raw/game lib\KINGDOM HEARTS HD 1525 ReMIX\gameinfo.csv
# Game info for Kingdom Rush 5 Alliance TD saved at ../data/raw/game lib\Kingdom Rush 5 Alliance TD\gameinfo.csv
# Game info for Knowledge or know Lady saved at ../data/raw/game lib\Knowledge or know Lady\gameinfo.csv
# Game info for Le Mans Ultimate saved at ../data/raw/game lib\Le Mans Ultimate\gameinfo.csv
# Game info for Legend of Mortal saved at ../data/raw/game lib\Legend of Mortal\gameinfo.csv
# Game info for Lightyear Frontier saved at ../data/raw/game lib\Lightyear Frontier\gameinfo.csv
# Game info for Like a Dragon Infinite Wealth saved at ../data/raw/game lib\Like a Dragon Infinite Wealth\gameinfo.csv
# Game info for Little Kitty Big City saved at ../data/raw/game lib\Little Kitty Big City\gameinfo.csv
# Game info for Living With Sister Monochrome Fantasy saved at ../data/raw/game lib\Living With Sister Monochrome Fantasy\gameinfo.csv
# Game info for LOCKDOWN Protocol saved at ../data/raw/game lib\LOCKDOWN Protocol\gameinfo.csv
# Game info for Lost Castle 2 saved at ../data/raw/game lib\Lost Castle 2\gameinfo.csv
# Game info for Lust Goddess saved at ../data/raw/game lib\Lust Goddess\gameinfo.csv
# Game info for Mad Island saved at ../data/raw/game lib\Mad Island\gameinfo.csv
# Game info for Manor Lords saved at ../data/raw/game lib\Manor Lords\gameinfo.csv
# Game info for MARVEL vs CAPCOM Fighting Collection Arcade Classics saved at ../data/raw/game lib\MARVEL vs CAPCOM Fighting Collection Arcade Classics\gameinfo.csv
# Game info for Men of War 2 saved at ../data/raw/game lib\Men of War 2\gameinfo.csv
# Game info for Millennia saved at ../data/raw/game lib\Millennia\gameinfo.csv
# Game info for Murders on the Yangtze River saved at ../data/raw/game lib\Murders on the Yangtze River\gameinfo.csv
# Game info for NBA 2K25 saved at ../data/raw/game lib\NBA 2K25\gameinfo.csv
# Game info for New Cycle saved at ../data/raw/game lib\New Cycle\gameinfo.csv
# Game info for Nightingale saved at ../data/raw/game lib\Nightingale\gameinfo.csv
# Game info for Nine Sols saved at ../data/raw/game lib\Nine Sols\gameinfo.csv
# Game info for No Rest for the Wicked saved at ../data/raw/game lib\No Rest for the Wicked\gameinfo.csv
# Game info for Nobody Wants to Die saved at ../data/raw/game lib\Nobody Wants to Die\gameinfo.csv
# Game info for Norland saved at ../data/raw/game lib\Norland\gameinfo.csv
# Game info for Once Human saved at ../data/raw/game lib\Once Human\gameinfo.csv
# Game info for Out of the Park Baseball 25 saved at ../data/raw/game lib\Out of the Park Baseball 25\gameinfo.csv
# Game info for Outpost Infinity Siege saved at ../data/raw/game lib\Outpost Infinity Siege\gameinfo.csv
# Game info for Pacific Drive saved at ../data/raw/game lib\Pacific Drive\gameinfo.csv
# Game info for Palia saved at ../data/raw/game lib\Palia\gameinfo.csv
# Game info for Palworld saved at ../data/raw/game lib\Palworld\gameinfo.csv
# Game info for PANICORE saved at ../data/raw/game lib\PANICORE\gameinfo.csv
# Game info for Pax Dei saved at ../data/raw/game lib\Pax Dei\gameinfo.csv
# Game info for Persona 3 Reload saved at ../data/raw/game lib\Persona 3 Reload\gameinfo.csv
# Game info for Pixel Gun 3D PC Edition saved at ../data/raw/game lib\Pixel Gun 3D PC Edition\gameinfo.csv
# Game info for Proud To Love saved at ../data/raw/game lib\Proud To Love\gameinfo.csv
# Game info for Rabbit and Steel saved at ../data/raw/game lib\Rabbit and Steel\gameinfo.csv
# Game info for Riven saved at ../data/raw/game lib\Riven\gameinfo.csv
# Game info for Rotwood saved at ../data/raw/game lib\Rotwood\gameinfo.csv
# Game info for Rustys Retirement saved at ../data/raw/game lib\Rustys Retirement\gameinfo.csv
# Game info for SAND LAND saved at ../data/raw/game lib\SAND LAND\gameinfo.csv
# Game info for Senuas Saga Hellblade 2 saved at ../data/raw/game lib\Senuas Saga Hellblade 2\gameinfo.csv
# Game info for shapez 2 saved at ../data/raw/game lib\shapez 2\gameinfo.csv
# Game info for Shin Megami Tensei 5 Vengeance saved at ../data/raw/game lib\Shin Megami Tensei 5 Vengeance\gameinfo.csv
# Game info for Sins of a Solar Empire 2 saved at ../data/raw/game lib\Sins of a Solar Empire 2\gameinfo.csv
# Game info for Sky Children of the Light saved at ../data/raw/game lib\Sky Children of the Light\gameinfo.csv
# Game info for SMITE 2 saved at ../data/raw/game lib\SMITE 2\gameinfo.csv
# Game info for Soulmask saved at ../data/raw/game lib\Soulmask\gameinfo.csv
# Game info for SOUTH PARK SNOW DAY saved at ../data/raw/game lib\SOUTH PARK SNOW DAY\gameinfo.csv
# Game info for Star Trucker saved at ../data/raw/game lib\Star Trucker\gameinfo.csv
# Game info for STAR WARS Battlefront Classic Collection saved at ../data/raw/game lib\STAR WARS Battlefront Classic Collection\gameinfo.csv
# Game info for Starward saved at ../data/raw/game lib\Starward\gameinfo.csv
# Game info for Still Wakes the Deep saved at ../data/raw/game lib\Still Wakes the Deep\gameinfo.csv
# Game info for Stormgate saved at ../data/raw/game lib\Stormgate\gameinfo.csv
# Game info for Suicide Squad Kill the Justice League saved at ../data/raw/game lib\Suicide Squad Kill the Justice League\gameinfo.csv
# Game info for Summer Clover saved at ../data/raw/game lib\Summer Clover\gameinfo.csv
# Game info for Summoners War saved at ../data/raw/game lib\Summoners War\gameinfo.csv
# Game info for Supermarket Simulator saved at ../data/raw/game lib\Supermarket Simulator\gameinfo.csv
# Game info for Superscout saved at ../data/raw/game lib\Superscout\gameinfo.csv
# Game info for Sword of Convallaria saved at ../data/raw/game lib\Sword of Convallaria\gameinfo.csv
# Game info for Tactical Breach Wizards saved at ../data/raw/game lib\Tactical Breach Wizards\gameinfo.csv
# Game info for Taxi Life A City Driving Simulator saved at ../data/raw/game lib\Taxi Life A City Driving Simulator\gameinfo.csv
# Game info for TEKKEN 8 saved at ../data/raw/game lib\TEKKEN 8\gameinfo.csv
# Game info for Terminator Dark Fate  Defiance saved at ../data/raw/game lib\Terminator Dark Fate  Defiance\gameinfo.csv
# Game info for TerraTech Worlds saved at ../data/raw/game lib\TerraTech Worlds\gameinfo.csv
# Game info for Test Drive Unlimited Solar Crown saved at ../data/raw/game lib\Test Drive Unlimited Solar Crown\gameinfo.csv
# Game info for Thank Goodness Youre Here saved at ../data/raw/game lib\Thank Goodness Youre Here\gameinfo.csv
# Game info for The Bridge Curse 2 The Extrication saved at ../data/raw/game lib\The Bridge Curse 2 The Extrication\gameinfo.csv
# Game info for The Casting of Frank Stone saved at ../data/raw/game lib\The Casting of Frank Stone\gameinfo.csv
# Game info for The Crew Motorfest saved at ../data/raw/game lib\The Crew Motorfest\gameinfo.csv
# Game info for The Crust saved at ../data/raw/game lib\The Crust\gameinfo.csv
# Game info for The First Descendant saved at ../data/raw/game lib\The First Descendant\gameinfo.csv
# Game info for The Hungry Lamb Traveling in the Late Ming Dynasty saved at ../data/raw/game lib\The Hungry Lamb Traveling in the Late Ming Dynasty\gameinfo.csv
# Game info for The Lord of the Rings Return to Moria saved at ../data/raw/game lib\The Lord of the Rings Return to Moria\gameinfo.csv
# Game info for The Thaumaturge saved at ../data/raw/game lib\The Thaumaturge\gameinfo.csv
# Game info for Tomb Raider 1 2 3 Remastered Starring Lara Croft saved at ../data/raw/game lib\Tomb Raider 1 2 3 Remastered Starring Lara Croft\gameinfo.csv
# Game info for TopSpin 2K25 saved at ../data/raw/game lib\TopSpin 2K25\gameinfo.csv
# Game info for Town of Sins saved at ../data/raw/game lib\Town of Sins\gameinfo.csv
# Game info for UNDER NIGHT INBIRTH 2 SysCeles saved at ../data/raw/game lib\UNDER NIGHT INBIRTH 2 SysCeles\gameinfo.csv
# Game info for Visions of Mana saved at ../data/raw/game lib\Visions of Mana\gameinfo.csv
# Game info for Warhammer 40000 Space Marine 2 saved at ../data/raw/game lib\Warhammer 40000 Space Marine 2\gameinfo.csv
# Game info for Winter Memories saved at ../data/raw/game lib\Winter Memories\gameinfo.csv
# Game info for WWE 2K24 saved at ../data/raw/game lib\WWE 2K24\gameinfo.csv
# ALL TASKS DONE!!!!!!
